# %%
# %pip install git+http://github.com/gradhep/relaxed.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+http://github.com/gradhep/relaxed.git
#   Cloning http://github.com/gradhep/relaxed.git to /tmp/pip-req-build-8d0jk9vp
#   Running command git clone -q http://github.com/gradhep/relaxed.git /tmp/pip-req-build-8d0jk9vp
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pyhf in /home/jovyan/.local/lib/python3.8/site-packages (from relaxed==0.0.7.dev3+g10c271b) (0.5.1.dev11)
# Requirement already satisfied: jax-fixedpoint==0.0.4 in /home/jovyan/.local/lib/python3.8/site-packages (from relaxed==0.0.7.dev3+g10c271b) (0.0.4)
# Requirement already satisfied: jax==0.1.71 in /home/jovyan/.local/lib/python3.8/site-packages (from relaxed==0.0.7.dev3+g10c271b) (0.1.71)
# Requirement already satisfied: immutables in /home/jovyan/.local/lib/python3.8/site-packages (from relaxed==0.0.7.dev3+g10c271b) (0.16)
# Requirement already satisfied: jaxlib==0.1.50 in /home/jovyan/.local/lib/python3.8/site-packages (from relaxed==0.0.7.dev3+g10c271b) (0.1.50)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from jax==0.1.71->relaxed==0.0.7.dev3+g10c271b) (0.10.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.8/dist-packages (from jax==0.1.71->relaxed==0.0.7.dev3+g10c271b) (1.21.0)
# Requirement already satisfied: opt-einsum in /home/jovyan/.local/lib/python3.8/site-packages (from jax==0.1.71->relaxed==0.0.7.dev3+g10c271b) (3.3.0)
# Requirement already satisfied: hypothesis in /home/jovyan/.local/lib/python3.8/site-packages (from jax-fixedpoint==0.0.4->relaxed==0.0.7.dev3+g10c271b) (6.23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from jax-fixedpoint==0.0.4->relaxed==0.0.7.dev3+g10c271b) (1.7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from absl-py->jax==0.1.71->relaxed==0.0.7.dev3+g10c271b) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from hypothesis->jax-fixedpoint==0.0.4->relaxed==0.0.7.dev3+g10c271b) (21.2.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/jovyan/.local/lib/python3.8/site-packages (from hypothesis->jax-fixedpoint==0.0.4->relaxed==0.0.7.dev3+g10c271b) (2.4.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from pyhf->relaxed==0.0.7.dev3+g10c271b) (3.2.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.8/dist-packages (from pyhf->relaxed==0.0.7.dev3+g10c271b) (7.1.2)
# Requirement already satisfied: tqdm in /home/jovyan/.local/lib/python3.8/site-packages (from pyhf->relaxed==0.0.7.dev3+g10c271b) (4.62.3)
# Requirement already satisfied: jsonpatch in /home/jovyan/.local/lib/python3.8/site-packages (from pyhf->relaxed==0.0.7.dev3+g10c271b) (1.32)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from pyhf->relaxed==0.0.7.dev3+g10c271b) (5.4.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.2.0->pyhf->relaxed==0.0.7.dev3+g10c271b) (0.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.2.0->pyhf->relaxed==0.0.7.dev3+g10c271b) (57.0.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jovyan/.local/lib/python3.8/site-packages (from jsonpatch->pyhf->relaxed==0.0.7.dev3+g10c271b) (2.1)
# Building wheels for collected packages: relaxed
#   Building wheel for relaxed (PEP 517) ... done
#   Created wheel for relaxed: filename=relaxed-0.0.7.dev3+g10c271b-py3-none-any.whl size=11791 sha256=2f349af29c9dcfe33fb88ba8e1712a797e15912e90e476369dcd050a16c0aaea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_moyvpsk/wheels/5f/8b/b6/ee38b54939f873e1c0e7c516d2f63f5d537ea92a9c95d046ae
# Successfully built relaxed
# Installing collected packages: relaxed
#   Attempting uninstall: relaxed
#     Found existing installation: relaxed 0.0.6
#     Uninstalling relaxed-0.0.6:
#       Successfully uninstalled relaxed-0.0.6
# Successfully installed relaxed-0.0.7.dev3+g10c271b
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import relaxed
from relaxed import fit, infer

# %%
from __future__ import annotations
import jax
import jax.numpy as jnp

from jax.random import PRNGKey, multivariate_normal

import pyhf
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

from typing import Callable, Any

from unittest.mock import patch
import sys

jax_backend = pyhf.tensor.jax_backend(precision="64b")
pyhf.set_backend(jax_backend)


@patch("pyhf.default_backend", new=jax_backend)
@patch.object(
    sys.modules["pyhf.interpolators.code0"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.interpolators.code1"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.interpolators.code2"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.interpolators.code4"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.interpolators.code4p"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.modifiers.shapefactor"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.modifiers.shapesys"], "default_backend", new=jax_backend
)
@patch.object(
    sys.modules["pyhf.modifiers.staterror"], "default_backend", new=jax_backend
)
def make_model(pars: jnp.array, bins=2) -> pyhf.Model:
    bounded_pars_upper = jnp.where(pars > 10.0, 10.0, pars)
    bounded_pars = jnp.where(bounded_pars_upper < -10.0, -10.0, bounded_pars_upper)
    if bins == 2:
        u1, d1 = bounded_pars
        u = jnp.array([u1, -u1])
        d = jnp.array([d1, -d1])

        sig = jnp.array([5, 11])
        nominal = jnp.array([50, 50])
        up = jnp.array([50, 50]) + u
        down = jnp.array([50, 50]) + d

    elif bins == 3:
        u1, u2, d1, d2 = bounded_pars
        u = jnp.array([u1, u2, -u1 - u2])
        d = jnp.array([d1, d2, -d1 - d2])

        sig = jnp.array([2, 5, 10])
        nominal = jnp.array([50, 50, 50])
        up = jnp.array([50, 50, 50]) + u
        down = jnp.array([50, 50, 50]) + d

    m = {
        "channels": [
            {
                "name": "singlechannel",
                "samples": [
                    {
                        "name": "signal",
                        "data": sig,
                        "modifiers": [
                            {"name": "mu", "type": "normfactor", "data": None}
                        ],
                    },
                    {
                        "name": "background",
                        "data": nominal,
                        "modifiers": [
                            {
                                "name": "bkguncrt",
                                "type": "histosys",
                                "data": {"hi_data": up, "lo_data": down},
                            }
                        ],
                    },
                ],
            }
        ]
    }
    return pyhf.Model(m)


def model_and_bonlypars(pars: jnp.array) -> tuple(pyhf.Model, jnp.array):
    m = make_model(pars)
    bonly_pars = jnp.array(m.config.suggested_init()).at[m.config.poi_index].set(0.0)
    return m, bonly_pars


def fisher_info_covariance(
    bestfit_pars: jnp.array, m: pyhf.Model, observed_data: jnp.array
) -> jnp.array:
    return jnp.linalg.inv(
        jax.hessian(lambda lhood_pars: -m.logpdf(lhood_pars, observed_data)[0])(
            bestfit_pars
        )
    )


def gaussian_logpdf(
    bestfit_pars: jnp.array, data: jnp.array, cov: jnp.array
) -> jnp.array:
    return jax.scipy.stats.multivariate_normal.logpdf(data, bestfit_pars, cov).reshape(
        1
    )


def model_gaussianity(
    m: pyhf.Model,
    bestfit_pars: jnp.array,
    cov_approx: jnp.array,
    observed_data: jnp.array,
) -> jnp.array:
    # - compare the likelihood of the fitted model with a gaussian approximation that has the same MLE (fitted_pars)
    # - do this across a number of points in parspace (sampled from the gaussian approx) and take the mean squared diff
    # - centre the values wrt the best-fit vals to scale the differences
    gaussian_parspace_samples = multivariate_normal(
        key=PRNGKey(1), mean=bestfit_pars, cov=cov_approx, shape=(100,)
    )

    relative_nlls_model = jax.vmap(
        lambda pars, data: -(
            m.logpdf(pars, data)[0] - m.logpdf(bestfit_pars, data)[0]
        ),  # scale origin to bestfit pars
        in_axes=(0, None),
    )(gaussian_parspace_samples, observed_data)

    relative_nlls_gaussian = jax.vmap(
        lambda pars, data: -(
            gaussian_logpdf(pars, data, cov_approx)[0]
            - gaussian_logpdf(bestfit_pars, data, cov_approx)[0]
        ),  # data fixes the lhood shape
        in_axes=(0, None),
    )(gaussian_parspace_samples, bestfit_pars)

    diffs = relative_nlls_model - relative_nlls_gaussian
    return jnp.mean(diffs[jnp.isfinite(diffs)] ** 2, axis=0)


def metrics(
    bestfit_pars: jnp.array,
    m: pyhf.Model,
    observed_data: jnp.array,
    diff_pars: jnp.ndarray,
) -> jnp.array:
    cov_approx = fisher_info_covariance(bestfit_pars, m, observed_data)
    mu_idx, y_idx = m.config.par_order.index("mu"), m.config.par_order.index("bkguncrt")
    mu_uncert2 = cov_approx[mu_idx, mu_idx]
    pull_width_metric2 = (1 - cov_approx[y_idx, y_idx]) ** 2
    gaussianity = model_gaussianity(m, bestfit_pars, cov_approx, observed_data)

    cls_fn = infer.make_hypotest(model_and_bonlypars)
    cls_obs = cls_fn(diff_pars, 1.0)["CLs"]

    return dict(
        cls_obs=cls_obs,
        mu_uncert2=mu_uncert2,
        pull_width_metric2=pull_width_metric2,
        gaussianity=gaussianity,
    )


def pipeline(pars: jnp.array, observed_data: jnp.array) -> jnp.array:
    m = make_model(pars)
    data = jnp.concatenate((observed_data, jnp.array(m.config.auxdata)))

    mle_pars = fit.global_fit(model_and_bonlypars)(jnp.array([0.0, 0.0]), pars)

    return jnp.array(list(metrics(mle_pars, m, data, pars).values()))

# %%
m, bp = model_and_bonlypars(jnp.array([1.0, 1.0]))
m.expected_data(bp)
# Out:
# DeviceArray([50., 50.,  0.], dtype=float64)

# %%
jax.jacrev(pipeline)(jnp.array([1.0, 1.0]), jnp.array([50.0, 50.0]))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-797420b85ca9> in <module>
# ----> 1 jax.jacrev(pipeline)(jnp.array([1.0, 1.0]), jnp.array([50.0, 50.0]))
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in jacfun(*args, **kwargs)
#    1162                                           require_static_args_hashable=False)
#    1163     tree_map(partial(_check_input_dtype_jacrev, holomorphic, allow_int), dyn_args)
# -> 1164     y, pullback = _vjp(f_partial, *dyn_args)
#    1165     tree_map(partial(_check_output_dtype_jacrev, holomorphic), y)
#    1166     jac = vmap(pullback)(_std_basis(y))
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in _vjp(fun, has_aux, reduce_axes, *primals)
#    2310   if not has_aux:
#    2311     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2312     out_primal, out_vjp = ad.vjp(
#    2313         flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2314     out_tree = out_tree()
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux, reduce_axes)
#     114 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     115   if not has_aux:
# --> 116     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     117   else:
#     118     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#     101   _, in_tree = tree_flatten(((primals, primals), {}))
#     102   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 103   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     104   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     105   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     511   with core.new_main(JaxprTrace) as main:
#     512     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 513     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     514     assert not env
#     515     del main, fun, env
#
# ~/.local/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# <ipython-input-1-c934ed915d4d> in pipeline(pars, observed_data)
#     177
#     178 def pipeline(pars: jnp.array, observed_data: jnp.array) -> jnp.array:
# --> 179     m = make_model(pars)
#     180     data = jnp.concatenate((observed_data, jnp.array(m.config.auxdata)))
#     181
#
# /usr/lib/python3.8/unittest/mock.py in patched(*args, **keywargs)
#    1337         @wraps(func)
#    1338         def patched(*args, **keywargs):
# -> 1339             with self.decoration_helper(patched,
#    1340                                         args,
#    1341                                         keywargs) as (newargs, newkeywargs):
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /usr/lib/python3.8/unittest/mock.py in decoration_helper(self, patched, args, keywargs)
#    1305         try:
#    1306             for patching in patched.patchings:
# -> 1307                 arg = patching.__enter__()
#    1308                 entered_patchers.append(patching)
#    1309                 if patching.attribute_name is not None:
#
# /usr/lib/python3.8/unittest/mock.py in __enter__(self)
#    1408             raise TypeError("Can't provide explicit spec_set *and* spec or autospec")
#    1409
# -> 1410         original, local = self.get_original()
#    1411
#    1412         if new is DEFAULT and autospec is None:
#
# /usr/lib/python3.8/unittest/mock.py in get_original(self)
#    1381
#    1382         if not self.create and original is DEFAULT:
# -> 1383             raise AttributeError(
#    1384                 "%s does not have the attribute %r" % (target, name)
#    1385             )
#
# AttributeError: <module 'pyhf.modifiers.staterror' from '/home/jovyan/.local/lib/python3.8/site-packages/pyhf/modifiers/staterror.py'> does not have the attribute 'default_backend'

# %%
import numpy as np

dense = 10
num_up, num_down = (dense, dense)

up_grid = np.linspace(-10, 0, num_up)
down_grid = np.linspace(-10, 0, num_down)

uv, dv = np.meshgrid(up_grid, down_grid)

# %%
pipe = partial(pipeline, observed_data=jnp.array([50.0, 50.0]))
values = np.array([pipe(jnp.array(a)) for a in np.vstack([uv.ravel(), dv.ravel()]).T])

# %%
import matplotlib.pyplot as plt

plt.rc("figure", figsize=[5, 5], dpi=120, facecolor="w")

fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

for i, (label, ax) in enumerate(
    zip(
        ["$CL_s$", r"$\sigma_{mu}^2$", r"$(1-\sigma_{\mathsf{np}})^2$", "gaussianity"],
        axs.ravel(),
    )
):
    p = ax.contourf(uv, dv, values[:, i].reshape((dense, dense)))
    plt.colorbar(p, ax=ax)
    ax.set_xlabel("u")
    ax.set_ylabel("d")
    ax.set_title(label)

plt.suptitle(
    "sig = [5,11], nom = [50,50]\nbkg_up = [nom+u,nom-u]\nbkg_down = [nom+d,nom-d]\n $|u|, |d|<10$"
)
plt.tight_layout()

# %%
mets = {
    metric: val
    for val, metric in zip(vals.T, ["cls", "mu_err^2", "[1-np_err]^2", "gaussianity"])
}

# %%
plt.rc("figure", figsize=[5, 5], dpi=120, facecolor="w")

values[:, 1] /= 2
values[:, 2] /= 4
values[:, 3] /= 200


p = plt.contourf(uv, dv, values.sum(axis=1).reshape((dense, dense)))

plt.xlabel("u")
plt.ylabel("d")

plt.suptitle(
    "sig = [5,11], nom = [50,50]\nbkg_up = [nom+u,nom-u]\nbkg_down = [nom+d,nom-d]\n $|u|, |d|<10$"
)
plt.tight_layout()

# %%
def evaluate_logpdf(
    logpdf: Callable[..., list[float]],
    data: np.ndarray,
    reference: np.ndarray,
    pdfargs: list[Any] = [],
) -> tuple[np.ndarray]:
    grid = xi, yi = np.mgrid[-4:4:51j, -2:2:51j]
    X = np.swapaxes(grid, 0, -1).reshape(-1, 2)
    r = jax.vmap(logpdf, in_axes=(0, *[None for i in range(len(pdfargs) + 1)]))(
        X, data, *pdfargs
    )
    zi = -2 * (r[:, 0].reshape(51, 51).T - logpdf(reference, data, *pdfargs))
    return xi, yi, zi

# %%
plt.rc("figure", figsize=[5, 5], dpi=120, facecolor="w")

fig, ax = plt.subplots()
from matplotlib.lines import Line2D

custom_lines = [
    Line2D([0], [0], color="C9", lw=2),
    Line2D([0], [0], color="C1", lw=2),
]


levels = [1, 2, 4, 8]
pars = up, down = jnp.array([-5, -10])
m = make_model(pars)
data = np.concatenate((np.ones(2) * 50.0, m.config.auxdata))
bestfit = pyhf.infer.mle.fit(data, m, init_pars=[0, 0])
model_eval = evaluate_logpdf(m.logpdf, data, bestfit)

cov_approx = fisher_info_covariance(bestfit, m, data)
gaussian_eval = evaluate_logpdf(gaussian_logpdf, bestfit, bestfit, [cov_approx])

ax.contourf(*model_eval, levels=levels)  # , colors="C9")
ax.contour(*gaussian_eval, levels=levels, colors="C1")
ax.set_xlabel(m.config.par_order[0])
ax.set_ylabel(m.config.par_order[1])

ax.legend(custom_lines, [f"model(u={up}, d={down})", "gaussian approx"])

# %%
cov_approx.shape[-2:]
# Out:
# (2, 2)

# %%
[i for i in range(0)]
# Out:
# []

# %%
Ts = 1 / (44 * 1000)
(1 / 880) / Ts
# Out:
# 50.0
